# %% [markdown]
# # PHP

# %% [markdown]
# ## 2. Superglobals

# %% [markdown]
# ### 2.2 Chessboard

# %% [markdown]
# Requirements:
#
# - The colour of the array is sored in a cookie
# - The default colour is grey, but it can be changed to magenta, yellow and cyan
# - The size of the chessboard is stored in the session and can be configured using the post method
# - The default size is 5 rows by 5 columns
# - The array is constructed from links that can be clicked
# - After clicking two points, a white line is drawn between the points
# - Multiple lines can be added
#
# When in doubt, run the acceptance tests :)

# %% [markdown]
# To start editing run:

# %%
! phpstorm project
# Out:
# CompileCommand: exclude com/intellij/openapi/vfs/impl/FilePartNodeRoot.trieDescend bool exclude = true
# Mar 07, 2024 5:27:09 PM java.util.prefs.FileSystemPreferences$1 run
# INFO: Created user preferences directory.
# 2024-03-07 17:27:11,197 [   1922]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.intellij.ae.database.core.baseEvents.fus.AddStatisticsEventLogListenerTemporary, plugin=com.jetbrains.ae.database)
# 2024-03-07 17:27:11,197 [   1922]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.jetbrains.rdserver.statistics.BackendStatisticsManager, plugin=com.jetbrains.codeWithMe)
# 2024-03-07 17:27:11,702 [   2427]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.search.FilenameIndex initializer requests com.intellij.ide.plugins.PluginUtil instance
# 2024-03-07 17:27:12,422 [   3147]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.lang.javascript.psi.jsdoc.impl.JSDocCustomTags initializer requests com.intellij.lang.javascript.JSDisposable instance
# 2024-03-07 17:27:20,508 [  11233]   WARN - #c.i.p.i.b.IdeStartupWizard - Timeout on waiting for initial start, proceeding without waiting, disabling the startup flow
# 2024-03-07 17:27:22,708 [  13433]   WARN - java.util.prefs - Prefs file removed in background /home/student/.java/.userPrefs/prefs.xml
# 2024-03-07 17:27:24,143 [  14868]   WARN - #c.i.d.PerformanceWatcherImpl - UI was frozen for 5648ms, details saved to /home/student/.cache/JetBrains/PhpStorm2023.3/log/threadDumps-freeze-20240307-172723-PS-233.14475.35-Unsafe.park-5sec
# 2024-03-07 17:27:48,892 [  39617]   WARN - #c.i.d.PerformanceWatcherImpl - UI was frozen for 24752ms, details saved to /home/student/.cache/JetBrains/PhpStorm2023.3/log/threadDumps-freeze-20240307-172729-PS-233.14475.35-Unsafe.park-24sec
# 2024-03-07 17:27:50,202 [  40927]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.LanguageSubstitutors initializer requests com.intellij.psi.LanguageSubstitutors instance
# 2024-03-07 17:27:50,317 [  41042]   WARN - #c.i.s.ComponentManagerImpl - org.zmlx.hg4idea.provider.HgChangeProvider initializer requests com.intellij.openapi.vcs.FileStatusFactory instance
# 2024-03-07 17:27:52,120 [  42845]   WARN - #c.i.i.s.p.i.SharedIndexChunkConfigurationImpl - Chunk bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35 is incompatible and is not registered for project 'project'
# 2024-03-07 17:27:53,442 [  44167]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./language-configuration.json` in bundle `/opt/PhpStorm-233.14475.35/plugins/textmate/lib/bundles/mdx`
# 2024-03-07 17:27:53,803 [  44528]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-03-07 17:27:54,011 [  44736]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-07 17:27:54,027 [  44752]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-07 17:27:54,274 [  44999]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.database.console.session.DatabaseSessionManager initializer requests com.intellij.database.console.session.DatabaseSessionViewService instance
# 2024-03-07 17:27:59,735 [  50460]   WARN - #c.i.o.a.i.ActionUpdater - 448 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-07 17:27:59,746 [  50471]   WARN - #c.i.o.a.i.ActionUpdater - 459 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-07 17:27:59,747 [  50472]   WARN - #c.i.o.a.i.ActionUpdater - 447 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-03-07 17:27:59,747 [  50472]   WARN - #c.i.o.a.i.ActionUpdater - 447 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-03-07 17:27:59,836 [  50561]   WARN - #c.i.o.a.i.ActionUpdater - 329 ms to grab EDT for FontEditorPreview$RestorePreviewTextAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$RestorePreviewTextAction)
# 2024-03-07 17:27:59,837 [  50562]   WARN - #c.i.o.a.i.ActionUpdater - 329 ms to grab EDT for FontEditorPreview$ToggleBoldFontAction#Update@ContextToolbar (com.intellij.application.options.colors.FontEditorPreview$ToggleBoldFontAction)
# 2024-03-07 17:27:59,837 [  50562]   WARN - #c.i.o.a.i.ActionUpdater - 328 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-03-07 17:27:59,837 [  50562]   WARN - #c.i.o.a.i.ActionUpdater - 328 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-03-07 17:28:00,603 [  51328]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:00,693 [  51418]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:00,697 [  51422]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:00,923 [  51648]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,048 [  51773]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,144 [  51869]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,303 [  52028]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,350 [  52075]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,567 [  52292]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:28:01,625 [  52350]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:29:14,270 [ 124995]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project project
# 2024-03-07 17:38:09,104 [ 659829]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-03-07 17:38:14,642 [ 665367]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:38:14,648 [ 665373]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:38:14,658 [ 665383]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:39:36,383 [ 747108]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:39:58,650 [ 769375]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,651 [ 769376]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,731 [ 769456]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,740 [ 769465]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,749 [ 769474]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,750 [ 769475]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,751 [ 769476]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:39:58,752 [ 769477]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-07 17:41:13,501 [ 844226]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,513 [ 844238]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,522 [ 844247]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,527 [ 844252]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,534 [ 844259]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,544 [ 844269]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,548 [ 844273]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,552 [ 844277]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,556 [ 844281]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,561 [ 844286]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,565 [ 844290]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:13,565 [ 844290]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:41:14,475 [ 845200]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:43:24,196 [ 974921]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-07 17:48:41,410 [1292135] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-07 17:48:41,411 [1292136] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-12 23:42:16,493 [454507218] SEVERE - #c.i.c.ProblemDescriptorBase - Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# java.lang.Throwable: Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# 	at com.intellij.openapi.diagnostic.Logger.error(Logger.java:376)
# 	at com.intellij.codeInspection.ProblemDescriptorBase.<init>(ProblemDescriptorBase.java:65)
# 	at com.intellij.codeInspection.InspectionManagerBase.createProblemDescriptor(InspectionManagerBase.java:97)
# 	at com.intellij.codeInspection.ProblemsHolder.registerProblemForReference(ProblemsHolder.java:108)
# 	at com.intellij.codeInspection.htmlInspections.HtmlWrongAttributeValueInspection.checkAttributeValue(HtmlWrongAttributeValueInspection.kt:23)
# 	at com.intellij.codeInspection.htmlInspections.HtmlLocalInspectionTool$1.visitXmlAttributeValue(HtmlLocalInspectionTool.java:86)
# 	at com.intellij.psi.impl.source.xml.XmlAttributeValueImpl.accept(XmlAttributeValueImpl.java:44)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:292)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:278)
# 	at java.base/java.util.concurrent.ForkJoinTask$AdaptedCallable.exec(ForkJoinTask.java:1428)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1182)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1655)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1622)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
# 2024-03-12 23:42:16,511 [454507236] SEVERE - #c.i.c.ProblemDescriptorBase - Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# java.lang.Throwable: Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# 	at com.intellij.openapi.diagnostic.Logger.error(Logger.java:376)
# 	at com.intellij.codeInspection.ProblemDescriptorBase.<init>(ProblemDescriptorBase.java:65)
# 	at com.intellij.codeInspection.InspectionManagerBase.createProblemDescriptor(InspectionManagerBase.java:97)
# 	at com.intellij.codeInspection.ProblemsHolder.registerProblemForReference(ProblemsHolder.java:108)
# 	at com.intellij.codeInspection.htmlInspections.HtmlWrongAttributeValueInspection.checkAttributeValue(HtmlWrongAttributeValueInspection.kt:23)
# 	at com.intellij.codeInspection.htmlInspections.HtmlLocalInspectionTool$1.visitXmlAttributeValue(HtmlLocalInspectionTool.java:86)
# 	at com.intellij.psi.impl.source.xml.XmlAttributeValueImpl.accept(XmlAttributeValueImpl.java:44)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:292)
# 	at com.intellij.concurrency.JobLauncherImpl.processQueue(JobLauncherImpl.java:359)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.processInOrder(InspectionRunner.java:324)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.visitElements(InspectionRunner.java:297)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspect$4(InspectionRunner.java:140)
# 	at com.intellij.codeInspection.InspectionEngine.withSession(InspectionEngine.java:246)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspect(InspectionRunner.java:126)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspectInjectedPsi$17(InspectionRunner.java:453)
# 	at com.intellij.concurrency.ApplierCompleter.execAndForkSubTasks(ApplierCompleter.java:139)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.concurrency.ApplierCompleter.lambda$wrapInReadActionAndIndicator$1(ApplierCompleter.java:96)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.ApplierCompleter.wrapInReadActionAndIndicator(ApplierCompleter.java:108)
# 	at com.intellij.concurrency.ApplierCompleter.lambda$compute$0(ApplierCompleter.java:86)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.concurrency.ApplierCompleter.compute(ApplierCompleter.java:86)
# 	at com.intellij.concurrency.JobLauncherImpl.invokeConcurrentlyUnderProgress(JobLauncherImpl.java:63)
# 	at com.intellij.concurrency.JobLauncher.invokeConcurrentlyUnderProgress(JobLauncher.java:51)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspectInjectedPsi(InspectionRunner.java:434)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.visitElements(InspectionRunner.java:300)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspect$4(InspectionRunner.java:149)
# 	at com.intellij.codeInspection.InspectionEngine.withSession(InspectionEngine.java:246)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspect(InspectionRunner.java:126)
# 	at com.intellij.codeInsight.daemon.impl.LocalInspectionsPass.collectInformationWithProgress(LocalInspectionsPass.java:113)
# 	at com.intellij.codeInsight.daemon.impl.ProgressableTextEditorHighlightingPass.doCollectInformation(ProgressableTextEditorHighlightingPass.java:80)
# 	at com.intellij.codeHighlighting.TextEditorHighlightingPass.collectInformation(TextEditorHighlightingPass.java:55)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$1(PassExecutorService.java:406)
# 	at com.intellij.platform.diagnostic.telemetry.helpers.TraceKt.runWithSpanIgnoreThrows(trace.kt:76)
# 	at com.intellij.platform.diagnostic.telemetry.helpers.TraceUtil.runWithSpanThrows(TraceUtil.java:34)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$2(PassExecutorService.java:401)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$3(PassExecutorService.java:392)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.doRun(PassExecutorService.java:391)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$run$0(PassExecutorService.java:367)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.run(PassExecutorService.java:365)
# 	at com.intellij.concurrency.JobLauncherImpl$VoidForkJoinTask$1.exec(JobLauncherImpl.java:187)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1182)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1655)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1622)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
# 2024-03-12 23:42:16,513 [454507238] SEVERE - #c.i.c.ProblemDescriptorBase - PhpStorm 2023.3.4  Build #PS-233.14475.35
# 2024-03-12 23:42:16,516 [454507241] SEVERE - #c.i.c.ProblemDescriptorBase - PhpStorm 2023.3.4  Build #PS-233.14475.35
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - JDK: 17.0.10; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - OS: Linux
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - JDK: 17.0.10; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - OS: Linux
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - Last Action: SaveAll
# 2024-03-12 23:42:16,517 [454507242] SEVERE - #c.i.c.ProblemDescriptorBase - Last Action: SaveAll
# 2024-03-12 23:42:18,577 [454509302] SEVERE - #c.i.c.ProblemDescriptorBase - Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# java.lang.Throwable: Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# 	at com.intellij.openapi.diagnostic.Logger.error(Logger.java:376)
# 	at com.intellij.codeInspection.ProblemDescriptorBase.<init>(ProblemDescriptorBase.java:65)
# 	at com.intellij.codeInspection.InspectionManagerBase.createProblemDescriptor(InspectionManagerBase.java:97)
# 	at com.intellij.codeInspection.ProblemsHolder.registerProblemForReference(ProblemsHolder.java:108)
# 	at com.intellij.codeInspection.htmlInspections.HtmlWrongAttributeValueInspection.checkAttributeValue(HtmlWrongAttributeValueInspection.kt:23)
# 	at com.intellij.codeInspection.htmlInspections.HtmlLocalInspectionTool$1.visitXmlAttributeValue(HtmlLocalInspectionTool.java:86)
# 	at com.intellij.psi.impl.source.xml.XmlAttributeValueImpl.accept(XmlAttributeValueImpl.java:44)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:292)
# 	at com.intellij.concurrency.JobLauncherImpl.processQueue(JobLauncherImpl.java:359)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.processInOrder(InspectionRunner.java:324)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.visitElements(InspectionRunner.java:297)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspect$4(InspectionRunner.java:140)
# 	at com.intellij.codeInspection.InspectionEngine.withSession(InspectionEngine.java:246)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspect(InspectionRunner.java:126)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspectInjectedPsi$17(InspectionRunner.java:453)
# 	at com.intellij.concurrency.ApplierCompleter.execAndForkSubTasks(ApplierCompleter.java:139)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.concurrency.ApplierCompleter.lambda$wrapInReadActionAndIndicator$1(ApplierCompleter.java:96)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.ApplierCompleter.wrapInReadActionAndIndicator(ApplierCompleter.java:108)
# 	at com.intellij.concurrency.ApplierCompleter.lambda$compute$0(ApplierCompleter.java:86)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.concurrency.ApplierCompleter.compute(ApplierCompleter.java:86)
# 	at java.base/java.util.concurrent.CountedCompleter.exec(CountedCompleter.java:754)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1182)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1655)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1622)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
# 2024-03-12 23:42:18,588 [454509313] SEVERE - #c.i.c.ProblemDescriptorBase - PhpStorm 2023.3.4  Build #PS-233.14475.35
# 2024-03-12 23:42:18,588 [454509313] SEVERE - #c.i.c.ProblemDescriptorBase - JDK: 17.0.10; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2024-03-12 23:42:18,588 [454509313] SEVERE - #c.i.c.ProblemDescriptorBase - OS: Linux
# 2024-03-12 23:42:18,588 [454509313] SEVERE - #c.i.c.ProblemDescriptorBase - Last Action: SaveAll
# 2024-03-12 23:45:05,877 [454676602]   WARN - #c.j.p.PhpIndex - Invalid Signature ';
# header(")'
# 2024-03-12 23:45:06,270 [454676995]   WARN - #c.j.p.PhpIndex - Invalid Signature ';
# header(")'
# 2024-03-12 23:45:08,642 [454679367]   WARN - #c.j.p.PhpIndex - Invalid Signature ';
# header(")'
# 2024-03-12 23:52:02,151 [455092876]   WARN - #c.j.p.PhpIndex - Invalid Signature '\class-string<#ᢐ\T.>'
# 2024-03-12 23:53:07,988 [455158713]   WARN - #c.i.o.a.e.ActionUtil - Can not find action by id CompileDirty
# 2024-03-13 00:11:12,753 [456243478] SEVERE - #c.i.c.ProblemDescriptorBase - Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# java.lang.Throwable: Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# 	at com.intellij.openapi.diagnostic.Logger.error(Logger.java:376)
# 	at com.intellij.codeInspection.ProblemDescriptorBase.<init>(ProblemDescriptorBase.java:65)
# 	at com.intellij.codeInspection.InspectionManagerBase.createProblemDescriptor(InspectionManagerBase.java:97)
# 	at com.intellij.codeInspection.ProblemsHolder.registerProblemForReference(ProblemsHolder.java:108)
# 	at com.intellij.codeInspection.htmlInspections.HtmlWrongAttributeValueInspection.checkAttributeValue(HtmlWrongAttributeValueInspection.kt:23)
# 	at com.intellij.codeInspection.htmlInspections.HtmlLocalInspectionTool$1.visitXmlAttributeValue(HtmlLocalInspectionTool.java:86)
# 	at com.intellij.psi.impl.source.xml.XmlAttributeValueImpl.accept(XmlAttributeValueImpl.java:44)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:292)
# 	at com.intellij.concurrency.JobLauncherImpl.processQueue(JobLauncherImpl.java:359)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.processInOrder(InspectionRunner.java:324)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.visitElements(InspectionRunner.java:297)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspect$4(InspectionRunner.java:140)
# 	at com.intellij.codeInspection.InspectionEngine.withSession(InspectionEngine.java:246)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspect(InspectionRunner.java:126)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspectInjectedPsi$17(InspectionRunner.java:453)
# 	at com.intellij.concurrency.JobLauncherImpl.lambda$processImmediatelyIfTooFew$2(JobLauncherImpl.java:144)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl.lambda$processImmediatelyIfTooFew$3(JobLauncherImpl.java:140)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runReadAction(ApplicationImpl.java:878)
# 	at com.intellij.concurrency.JobLauncherImpl.processImmediatelyIfTooFew(JobLauncherImpl.java:151)
# 	at com.intellij.concurrency.JobLauncherImpl.invokeConcurrentlyUnderProgress(JobLauncherImpl.java:47)
# 	at com.intellij.concurrency.JobLauncher.invokeConcurrentlyUnderProgress(JobLauncher.java:51)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspectInjectedPsi(InspectionRunner.java:434)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.visitElements(InspectionRunner.java:300)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$inspect$4(InspectionRunner.java:140)
# 	at com.intellij.codeInspection.InspectionEngine.withSession(InspectionEngine.java:246)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.inspect(InspectionRunner.java:126)
# 	at com.intellij.codeInsight.daemon.impl.LocalInspectionsPass.collectInformationWithProgress(LocalInspectionsPass.java:113)
# 	at com.intellij.codeInsight.daemon.impl.ProgressableTextEditorHighlightingPass.doCollectInformation(ProgressableTextEditorHighlightingPass.java:80)
# 	at com.intellij.codeHighlighting.TextEditorHighlightingPass.collectInformation(TextEditorHighlightingPass.java:55)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$1(PassExecutorService.java:406)
# 	at com.intellij.platform.diagnostic.telemetry.helpers.TraceKt.runWithSpanIgnoreThrows(trace.kt:76)
# 	at com.intellij.platform.diagnostic.telemetry.helpers.TraceUtil.runWithSpanThrows(TraceUtil.java:34)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$2(PassExecutorService.java:401)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$doRun$3(PassExecutorService.java:392)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.doRun(PassExecutorService.java:391)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.lambda$run$0(PassExecutorService.java:367)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.PassExecutorService$ScheduledPass.run(PassExecutorService.java:365)
# 	at com.intellij.concurrency.JobLauncherImpl$VoidForkJoinTask$1.exec(JobLauncherImpl.java:187)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1182)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1655)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1622)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
# 2024-03-13 00:11:12,756 [456243481] SEVERE - #c.i.c.ProblemDescriptorBase - PhpStorm 2023.3.4  Build #PS-233.14475.35
# 2024-03-13 00:11:12,756 [456243481] SEVERE - #c.i.c.ProblemDescriptorBase - JDK: 17.0.10; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2024-03-13 00:11:12,756 [456243481] SEVERE - #c.i.c.ProblemDescriptorBase - OS: Linux
# 2024-03-13 00:11:12,756 [456243481] SEVERE - #c.i.c.ProblemDescriptorBase - Last Action: EditorBackSpace
# 2024-03-13 00:12:37,386 [456328111] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-13 00:12:37,387 [456328112] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-13 00:13:29,777 [456380502] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-13 00:13:29,777 [456380502] SEVERE - com.jediterm.terminal.model.TerminalTextBuffer - Attempt to get line out of bounds: 11 >= 11
# 2024-03-13 00:20:57,858 [456828583]   WARN - #c.j.p.PhpIndex - Invalid Signature '\class-string<#ᢐ\T.>'
# 2024-03-13 00:23:19,002 [456969727]   WARN - #c.j.p.PhpIndex - Invalid Signature '\class-string<#ᢐ\T.>'
# 2024-03-13 00:25:06,348 [457077073] SEVERE - #c.i.c.ProblemDescriptorBase - Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# java.lang.Throwable: Empty PSI elements must not be passed to createDescriptor. Start: PsiElement(XML_ATTRIBUTE_VALUE), end: PsiElement(XML_ATTRIBUTE_VALUE), startContainingFile: HtmlFile:index.php
# 	at com.intellij.openapi.diagnostic.Logger.error(Logger.java:376)
# 	at com.intellij.codeInspection.ProblemDescriptorBase.<init>(ProblemDescriptorBase.java:65)
# 	at com.intellij.codeInspection.InspectionManagerBase.createProblemDescriptor(InspectionManagerBase.java:97)
# 	at com.intellij.codeInspection.ProblemsHolder.registerProblemForReference(ProblemsHolder.java:108)
# 	at com.intellij.codeInspection.htmlInspections.HtmlWrongAttributeValueInspection.checkAttributeValue(HtmlWrongAttributeValueInspection.kt:23)
# 	at com.intellij.codeInspection.htmlInspections.HtmlLocalInspectionTool$1.visitXmlAttributeValue(HtmlLocalInspectionTool.java:86)
# 	at com.intellij.psi.impl.source.xml.XmlAttributeValueImpl.accept(XmlAttributeValueImpl.java:44)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# ...
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:264)
# 	at com.intellij.util.flow.FlowKt.collectLatestUndispatched(flow.kt:66)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.handlePage(DocumentationUI.kt:143)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.access$handlePage(DocumentationUI.kt:47)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invokeSuspend(DocumentationUI.kt:99)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6$1.invoke(DocumentationUI.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invokeSuspend(flow.kt:68)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2$firstJob$1.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch$default(Builders.common.kt:47)
# 	at kotlinx.coroutines.BuildersKt.launch$default(Unknown Source)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invokeSuspend(flow.kt:67)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at com.intellij.util.flow.FlowKt$collectLatestUndispatched$2.invoke(flow.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:264)
# 	at com.intellij.util.flow.FlowKt.collectLatestUndispatched(flow.kt:66)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invokeSuspend(DocumentationUI.kt:98)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$6.invoke(DocumentationUI.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.<init>(DocumentationUI.kt:97)
# 	at com.intellij.lang.documentation.ide.impl.DocumentationTargetHoverInfo.createQuickDocComponent(DocumentationTargetHoverInfo.kt:103)
# 	at com.intellij.openapi.editor.EditorHoverInfo.createComponent(EditorHoverInfo.java:31)
# 	at com.intellij.openapi.editor.EditorMouseHoverPopupManager.lambda$scheduleProcessing$3(EditorMouseHoverPopupManager.java:183)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:209)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$100(TransactionGuardImpl.java:22)
# 	at com.intellij.openapi.application.TransactionGuardImpl$1.run(TransactionGuardImpl.java:191)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:843)
# 	at com.intellij.openapi.application.impl.ApplicationImpl$4.run(ApplicationImpl.java:463)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithEnabledImplicitRead(RwLockHolder.kt:75)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithImplicitRead(RwLockHolder.kt:67)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWithImplicitRead(ApplicationImpl.java:1436)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:82)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:124)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:44)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:318)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:792)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:739)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:733)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:399)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:86)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:761)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.kt:695)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent$lambda$12(IdeEventQueue.kt:589)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithoutImplicitRead(RwLockHolder.kt:44)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.kt:589)
# 	at com.intellij.ide.IdeEventQueue.access$_dispatchEvent(IdeEventQueue.kt:72)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:355)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:354)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computePrioritized(CoreProgressManager.java:793)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:354)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:349)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1014)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1014)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$7(IdeEventQueue.kt:349)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:848)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:391)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)
# 2024-03-14 00:00:00,477 [541971202]   WARN - #c.i.u.i.CachedImageIcon - Cannot get reflective icon (path=icons.PhpIcons.Trait)
# java.lang.ClassNotFoundException: icons.PhpIcons
# 	at com.intellij.util.lang.UrlClassLoader.findClass(UrlClassLoader.java:246)
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:592)
# 	at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:525)
# 	at com.intellij.ui.icons.ImageDataByPathLoaderKt.getReflectiveIcon(ImageDataByPathLoader.kt:169)
# 	at com.intellij.openapi.util.IconLoaderKt.findIconUsingDeprecatedImplementation(IconLoader.kt:369)
# 	at com.intellij.openapi.util.IconLoaderKt.findIconUsingDeprecatedImplementation$default(IconLoader.kt:354)
# 	at com.intellij.openapi.util.IconLoader.findIcon(IconLoader.kt:147)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.getIcon(ExtendableHTMLViewFactory.kt:143)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.invoke(ExtendableHTMLViewFactory.kt:134)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory$Extensions$IconsExtension.invoke(ExtendableHTMLViewFactory.kt:127)
# 	at com.intellij.util.ui.ExtendableHTMLViewFactory.create(ExtendableHTMLViewFactory.kt:41)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:112)
# 	at java.desktop/javax.swing.text.FlowView$LogicalView.loadChildren(FlowView.java:731)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.FlowView.loadChildren(FlowView.java:147)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.FlowView.setParent(FlowView.java:306)
# 	at java.desktop/javax.swing.text.html.ParagraphView.setParent(ParagraphView.java:75)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:114)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.html.BlockView.setParent(BlockView.java:72)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:114)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.html.BlockView.setParent(BlockView.java:72)
# 	at java.desktop/javax.swing.text.html.HTMLEditorKit$HTMLFactory$BodyBlockView.setParent(HTMLEditorKit.java:1476)
# 	at java.desktop/javax.swing.text.CompositeView.replace(CompositeView.java:219)
# 	at java.desktop/javax.swing.text.BoxView.replace(BoxView.java:182)
# 	at java.desktop/javax.swing.text.CompositeView.loadChildren(CompositeView.java:114)
# 	at java.desktop/javax.swing.text.CompositeView.setParent(CompositeView.java:139)
# 	at java.desktop/javax.swing.text.html.BlockView.setParent(BlockView.java:72)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI$RootView.setView(BasicTextUI.java:1432)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI.setView(BasicTextUI.java:713)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI.modelChanged(BasicTextUI.java:702)
# 	at java.desktop/javax.swing.plaf.basic.BasicTextUI$UpdateHandler.propertyChange(BasicTextUI.java:1919)
# 	at java.desktop/java.beans.PropertyChangeSupport.fire(PropertyChangeSupport.java:343)
# 	at java.desktop/java.beans.PropertyChangeSupport.firePropertyChange(PropertyChangeSupport.java:335)
# 	at java.desktop/java.beans.PropertyChangeSupport.firePropertyChange(PropertyChangeSupport.java:268)
# 	at java.desktop/java.awt.Component.firePropertyChange(Component.java:8759)
# 	at java.desktop/java.awt.Component.setFont(Component.java:1980)
# 	at java.desktop/java.awt.Container.setFont(Container.java:1780)
# 	at java.desktop/javax.swing.JComponent.setFont(JComponent.java:2810)
# 	at com.intellij.codeInsight.documentation.DocumentationEditorPane.applyFontProps(DocumentationEditorPane.java:205)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$7$1.emit(DocumentationUI.kt:104)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$7$1.emit(DocumentationUI.kt:103)
# 	at kotlinx.coroutines.flow.StateFlowImpl.collect(StateFlow.kt:396)
# 	at kotlinx.coroutines.flow.ReadonlySharedFlow.collect(Share.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$7.invokeSuspend(DocumentationUI.kt:103)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$7.invoke(DocumentationUI.kt)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI$7.invoke(DocumentationUI.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:44)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:112)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:126)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:56)
# 	at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 	at com.intellij.lang.documentation.ide.ui.DocumentationUI.<init>(DocumentationUI.kt:102)
# 	at com.intellij.lang.documentation.ide.impl.DocumentationTargetHoverInfo.createQuickDocComponent(DocumentationTargetHoverInfo.kt:103)
# 	at com.intellij.openapi.editor.EditorHoverInfo.createComponent(EditorHoverInfo.java:31)
# 	at com.intellij.openapi.editor.EditorMouseHoverPopupManager.lambda$scheduleProcessing$3(EditorMouseHoverPopupManager.java:183)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:209)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$100(TransactionGuardImpl.java:22)
# 	at com.intellij.openapi.application.TransactionGuardImpl$1.run(TransactionGuardImpl.java:191)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:843)
# 	at com.intellij.openapi.application.impl.ApplicationImpl$4.run(ApplicationImpl.java:463)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithEnabledImplicitRead(RwLockHolder.kt:75)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithImplicitRead(RwLockHolder.kt:67)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWithImplicitRead(ApplicationImpl.java:1436)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:82)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:124)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:44)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:318)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:792)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:739)
# 	at java.desktop/java.awt.EventQueue$3.run(EventQueue.java:733)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:399)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:86)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:761)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.kt:695)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent$lambda$12(IdeEventQueue.kt:589)
# 	at com.intellij.openapi.application.impl.RwLockHolder.runWithoutImplicitRead(RwLockHolder.kt:44)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.kt:589)
# 	at com.intellij.ide.IdeEventQueue.access$_dispatchEvent(IdeEventQueue.kt:72)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:355)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.compute(IdeEventQueue.kt:354)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computePrioritized(CoreProgressManager.java:793)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:354)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1.invoke(IdeEventQueue.kt:349)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1014)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1014)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$7(IdeEventQueue.kt:349)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:848)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:391)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)

# %% [markdown]
# Working application:
#
# ![01_initial](images/01_initial.jpg)
# ![02_click](images/02_click.jpg)
# ![03_clicked](images/03_clicked.jpg)
# ![04_click](images/04_click.jpg)
# ![05_clicked](images/05_clicked.jpg)
# ![06_change](images/06_change.jpg)
# ![07_changed](images/07_changed.jpg)
# ![08_color_change](images/08_color_change.jpg)
# ![09_color_changed](images/09_color_changed.jpg)
#
# More advanced example:
#
# ![11_restart](images/11_restart.jpg)
# ![12_click](images/12_click.jpg)
# ![13_click](images/13_click.jpg)
# ![14_click](images/14_click.jpg)
# ![15_click](images/15_click.jpg)
# ![16_done](images/16_done.jpg)

# %% [markdown]
# You can test your solution using included tests:

# %%
import subprocess
phpServer = subprocess.Popen(['php', '-S', 'localhost:8888', '-t', 'project/'])

# %%
! cd tests && composer install && vendor/bin/codecept run

# %%
phpServer.kill()
