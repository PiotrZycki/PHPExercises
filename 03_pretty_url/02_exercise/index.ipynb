# %% [markdown]
# # PHP

# %% [markdown]
# ## 3. Pretty URL

# %% [markdown]
# ### 3.2 Exercise

# %% [markdown]
# Refactor the code to use ```$_SERVER['REQUEST_URI']``` to handle all requests in a single ```index.php``` script.
#
# Final project structure:
#
# ```bash
# project/
# ├── public
# │   ├── index.php
# │   └── style.css
# └── views
#     ├── 404.php
#     ├── about.php
#     ├── home.php
#     ├── layout.php
#     ├── menu.php
#     ├── user.php
#     └── users.php
#
# 2 directories, 9 files
# ```
#
# To start editing the code run:

# %%
! phpstorm project
# Out:
# CompileCommand: exclude com/intellij/openapi/vfs/impl/FilePartNodeRoot.trieDescend bool exclude = true
# 2024-03-14 17:03:52,464 [   1084]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.intellij.ae.database.core.baseEvents.fus.AddStatisticsEventLogListenerTemporary, plugin=com.jetbrains.ae.database)
# 2024-03-14 17:03:52,465 [   1085]   WARN - #c.i.s.ComponentManagerImpl - `preload=true` must be used only for core services (service=com.jetbrains.rdserver.statistics.BackendStatisticsManager, plugin=com.jetbrains.codeWithMe)
# 2024-03-14 17:03:53,537 [   2157]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.search.FilenameIndex initializer requests com.intellij.ide.plugins.PluginUtil instance
# 2024-03-14 17:03:54,573 [   3193]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.lang.javascript.psi.jsdoc.impl.JSDocCustomTags initializer requests com.intellij.lang.javascript.JSDisposable instance
# 2024-03-14 17:03:54,963 [   3583]   WARN - #c.i.s.ComponentManagerImpl - org.zmlx.hg4idea.provider.HgChangeProvider initializer requests com.intellij.openapi.vcs.FileStatusFactory instance
# 2024-03-14 17:03:55,132 [   3752]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.LanguageSubstitutors initializer requests com.intellij.psi.LanguageSubstitutors instance
# 2024-03-14 17:03:55,862 [   4482]   WARN - #c.i.o.v.n.p.d.e.DurableEnumeratorFactory - [enumerator.mmapped]: .valueToId map is out-of-sync with .valuesLog data -> rebuilding it
# 2024-03-14 17:03:57,044 [   5664]   WARN - #c.i.o.a.i.ActionUpdater - 307 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-14 17:03:57,790 [   6410]   WARN - #c.i.o.a.i.ActionUpdater - 935 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-14 17:03:57,867 [   6487]   WARN - #c.i.o.a.i.ActionUpdater - 822 ms to grab EDT for ToolWindowHeader$2#GetChildren@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-14 17:03:58,512 [   7132]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./language-configuration.json` in bundle `/opt/PhpStorm-233.14475.35/plugins/textmate/lib/bundles/mdx`
# 2024-03-14 17:03:59,592 [   8212]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-03-14 17:04:00,779 [   9399]   WARN - #c.i.o.a.i.ActionUpdater - 729 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-03-14 17:04:00,782 [   9402]   WARN - #c.i.o.a.i.ActionUpdater - 725 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-14 17:07:17,432 [ 206052]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-14 17:07:17,442 [ 206062]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-14 17:07:17,859 [ 206479]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.database.console.session.DatabaseSessionManager initializer requests com.intellij.database.console.session.DatabaseSessionViewService instance
# 2024-03-14 17:07:18,129 [ 206749]   WARN - #c.i.o.a.i.ActionUpdater - 485 ms to grab EDT for ToolWindowHeader$2#Update@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2)
# 2024-03-14 17:07:18,131 [ 206751]   WARN - #c.i.o.a.i.ActionUpdater - 479 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-03-14 17:08:18,796 [ 267416]   WARN - #c.i.i.b.BrowserLauncherAppless - Cannot run program "/usr/bin/firefox": error=2, No such file or directory
# com.intellij.execution.process.ProcessNotCreatedException: Cannot run program "/usr/bin/firefox": error=2, No such file or directory
# 	at com.intellij.execution.configurations.GeneralCommandLine.createProcess(GeneralCommandLine.java:358)
# 	at com.intellij.execution.process.OSProcessHandler.startProcess(OSProcessHandler.java:84)
# 	at com.intellij.execution.process.OSProcessHandler.<init>(OSProcessHandler.java:44)
# 	at com.intellij.execution.process.CapturingProcessHandler.<init>(CapturingProcessHandler.java:20)
# 	at com.intellij.execution.process.CapturingProcessHandler$Silent.<init>(CapturingProcessHandler.java:82)
# 	at com.intellij.ide.browsers.BrowserLauncherAppless$spawn$2.invokeSuspend(BrowserLauncherAppless.kt:216)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.internal.LimitedDispatcher$Worker.run(LimitedDispatcher.kt:115)
# 	at kotlinx.coroutines.scheduling.TaskImpl.run(Tasks.kt:103)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# Caused by: java.io.IOException: Cannot run program "/usr/bin/firefox": error=2, No such file or directory
# 	at java.base/java.lang.ProcessBuilder.start(ProcessBuilder.java:1143)
# 	at java.base/java.lang.ProcessBuilder.start(ProcessBuilder.java:1073)
# 	at com.intellij.execution.configurations.GeneralCommandLine.createProcess(GeneralCommandLine.java:470)
# 	at com.intellij.execution.configurations.GeneralCommandLine.startProcess(GeneralCommandLine.java:443)
# 	at com.intellij.execution.configurations.GeneralCommandLine.createProcess(GeneralCommandLine.java:348)
# 	... 13 more
# Caused by: java.io.IOException: error=2, No such file or directory
# 	at java.base/java.lang.ProcessImpl.forkAndExec(Native Method)
# 	at java.base/java.lang.ProcessImpl.<init>(ProcessImpl.java:314)
# 	at java.base/java.lang.ProcessImpl.start(ProcessImpl.java:244)
# 	at java.base/java.lang.ProcessBuilder.start(ProcessBuilder.java:1110)
# 	... 17 more
# 2024-03-14 17:27:16,942 [1405562]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.psi.codeStyle.CodeStyleSettingsCustomizable initializer requests com.intellij.util.LocaleSensitiveApplicationCacheService instance
# IOStream.flush timed out
# 2024-03-17 12:04:13,587 [241222207]   WARN - #c.i.o.a.i.ActionUpdater - 474 ms to grab EDT for EditorMarkupModelImpl$TrafficLightAction#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$TrafficLightAction)
# 2024-03-17 12:04:13,587 [241222207]   WARN - #c.i.o.a.i.ActionUpdater - 474 ms to grab EDT for EditorMarkupModelImpl$1#Update@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-03-17 12:04:13,587 [241222207]   WARN - #c.i.o.a.i.ActionUpdater - 474 ms to grab EDT for JoinCallAction#Update@MainToolbar (com.jetbrains.rd.platform.codeWithMe.telephony.JoinCallAction)
# 2024-03-17 12:04:13,587 [241222207]   WARN - #c.i.o.a.i.ActionUpdater - 474 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-03-17 12:04:19,773 [241228393]   WARN - #c.i.o.a.e.ActionUtil - Can not find action by id CompileDirty
# 2024-03-17 17:33:14,965 [260963585]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-03-17 17:33:15,297 [260963917]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.psalm.PsalmSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.psalm]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-17 17:33:15,299 [260963919]   WARN - #c.i.i.s.i.StartupManagerImpl - Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# com.intellij.diagnostic.PluginException: Migrate com.jetbrains.php.tools.quality.phpstan.PhpStanSettingsTransferStartupActivity to ProjectActivity [Plugin: com.intellij.php.tools.quality.phpstan]
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.runPostStartupActivities(StartupManagerImpl.kt:277)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl.access$runPostStartupActivities(StartupManagerImpl.kt:69)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invokeSuspend(StartupManagerImpl.kt:192)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3$2.invoke(StartupManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:78)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:167)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.ide.startup.impl.StartupManagerImpl$runPostStartupActivities$3.invokeSuspend(StartupManagerImpl.kt:191)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:108)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:584)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:793)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:697)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:684)
# 2024-03-17 17:34:27,100 [261035720]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:35:45,990 [261114610]   WARN - #c.i.i.s.p.i.BundledSharedIndexPostStartupActivity - Skipped 1 pre-built shared indexes: bundled-js-predefined-1d06a55b98c1-985749b364ce-JavaScript-PS-233.14475.35
# 2024-03-17 17:35:51,392 [261120012]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:35:51,393 [261120013]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:35:51,394 [261120014]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:36:02,782 [261131402]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:36:03,388 [261132008]   WARN - #c.i.o.a.i.ActionUpdater - 373 ms to grab EDT for ReviewModeActionGroup#Update@EditorInspectionsToolbar (org.jetbrains.plugins.gitlab.mergerequest.ui.editor.action.ReviewModeActionGroup)
# 2024-03-17 17:36:03,389 [261132009]   WARN - #c.i.o.a.i.ActionUpdater - 373 ms to grab EDT for EditorMarkupModelImpl$1#GetChildren@EditorInspectionsToolbar (com.intellij.openapi.editor.impl.EditorMarkupModelImpl$1)
# 2024-03-17 17:36:27,498 [261156118]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,499 [261156119]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,532 [261156152]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,539 [261156159]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,542 [261156162]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,542 [261156162]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,543 [261156163]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:36:27,544 [261156164]   WARN - #org.editorconfig.language.schema.parser.EditorConfigJsonSchemaParser - Found illegal descriptor: {}
# 2024-03-17 17:38:28,147 [261276767]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,154 [261276774]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,155 [261276775]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,155 [261276775]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,156 [261276776]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,156 [261276776]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,201 [261276821]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,208 [261276828]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,215 [261276835]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,230 [261276850]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,234 [261276854]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,238 [261276858]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:28,980 [261277600]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,874 [261297494]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,885 [261297505]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,885 [261297505]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,930 [261297550]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,945 [261297565]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:48,950 [261297570]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:38:49,638 [261298258]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,907 [261479527]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,915 [261479535]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,916 [261479536]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,916 [261479536]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,917 [261479537]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,917 [261479537]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:50,991 [261479611]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:41:51,714 [261480334]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,771 [261491391]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,798 [261491418]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,842 [261491462]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,851 [261491471]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,867 [261491487]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,872 [261491492]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:02,879 [261491499]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:03,540 [261492160]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,306 [261492926]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,309 [261492929]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,348 [261492968]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,359 [261492979]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,363 [261492983]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:04,368 [261492988]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:42:05,023 [261493643]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,537 [261910157]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,545 [261910165]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,549 [261910169]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,562 [261910182]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,563 [261910183]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,649 [261910269]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:01,671 [261910291]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:02,600 [261911220]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:25,868 [261934488]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 17:49:26,052 [261934672]   WARN - #c.i.o.v.ExternallyAddedFilesProcessorImpl - Cannot find project config directory for non-default and non-directory based project tests
# 2024-03-17 18:07:24,508 [263013128]   WARN - #c.i.s.ComponentManagerImpl - com.intellij.usages.UsageNodePresentation initializer requests com.intellij.usageView.UsageTreeColorsScheme instance
# 2024-03-17 18:43:42,806 [265191426] SEVERE - #c.i.u.IdempotenceChecker - Non-idempotent computation: it returns different results when invoked multiple times or on different threads:
#   {} (class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement) != {} (class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement)
#   which is element of PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user and PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user
#   which is 0th element of [PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user, PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user] and [PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user, PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user]
#
# Recomputation gives [Lcom.intellij.psi.ResolveResult;@10361e55 (class [Lcom.intellij.psi.ResolveResult;) which is different from both values
# Recomputation log:
#   Resolving VariableImpl: user of class com.jetbrains.php.lang.psi.elements.impl.VariableImpl [Plugin: com.jetbrains.php]
# com.intellij.diagnostic.PluginException: Non-idempotent computation: it returns different results when invoked multiple times or on different threads:
#   {} (class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement) != {} (class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement)
#   which is element of PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user and PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user
#   which is 0th element of [PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user, PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user] and [PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user, PsiElementResolveResult with class com.jetbrains.php.lang.psi.stubs.indexes.PhpGlobalVariableFakeElement: user]
#
# Recomputation gives [Lcom.intellij.psi.ResolveResult;@10361e55 (class [Lcom.intellij.psi.ResolveResult;) which is different from both values
# Recomputation log:
#   Resolving VariableImpl: user of class com.jetbrains.php.lang.psi.elements.impl.VariableImpl [Plugin: com.jetbrains.php]
# 	at com.intellij.diagnostic.PluginProblemReporterImpl.createPluginExceptionByClass(PluginProblemReporterImpl.java:23)
# 	at com.intellij.diagnostic.PluginException.createByClass(PluginException.java:89)
# 	at com.intellij.util.IdempotenceChecker.reportFailure(IdempotenceChecker.java:97)
# 	at com.intellij.util.IdempotenceChecker.checkEquivalence(IdempotenceChecker.java:82)
# 	at com.intellij.psi.impl.source.resolve.ResolveCache.cache(ResolveCache.java:296)
# 	at com.intellij.psi.impl.source.resolve.ResolveCache.resolve(ResolveCache.java:224)
# 	at com.intellij.psi.impl.source.resolve.ResolveCache.resolveWithCaching(ResolveCache.java:158)
# 	at com.intellij.psi.impl.source.resolve.ResolveCache.resolveWithCaching(ResolveCache.java:145)
# 	at com.jetbrains.php.lang.psi.elements.impl.VariableImpl.multiResolve(VariableImpl.java:422)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpInferredArrayEmptinessProcessor.processEntryPointInstruction(PhpInferredArrayEmptinessProcessor.java:51)
# 	at com.jetbrains.php.codeInsight.controlFlow.instructions.impl.PhpEntryPointInstructionImpl.process(PhpEntryPointInstructionImpl.java:16)
# 	at com.jetbrains.php.codeInsight.controlFlow.PhpControlFlowUtil.processPredecessors(PhpControlFlowUtil.java:344)
# 	at com.jetbrains.php.codeInsight.controlFlow.PhpControlFlowUtil.processPredecessors(PhpControlFlowUtil.java:314)
# 	at com.jetbrains.php.codeInsight.controlFlow.PhpControlFlowUtil.processPredecessors(PhpControlFlowUtil.java:283)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpArrayIsAlwaysEmptyInspection.getAlwaysEmptyAssignmentInstruction(PhpArrayIsAlwaysEmptyInspection.java:115)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpArrayIsAlwaysEmptyInspection.getAlwaysEmptyInstruction(PhpArrayIsAlwaysEmptyInspection.java:100)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpArrayIsAlwaysEmptyInspection.getAlwaysEmptyInstruction(PhpArrayIsAlwaysEmptyInspection.java:75)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpArrayIsAlwaysEmptyInspection$1.doCheckArray(PhpArrayIsAlwaysEmptyInspection.java:50)
# 	at com.jetbrains.php.lang.inspections.controlFlow.dfa.PhpArrayIsAlwaysEmptyInspection$1.visitPhpArrayAccessExpression(PhpArrayIsAlwaysEmptyInspection.java:40)
# 	at com.jetbrains.php.lang.psi.elements.impl.ArrayAccessExpressionImpl.accept(ArrayAccessExpressionImpl.java:36)
# 	at com.jetbrains.php.lang.psi.elements.impl.PhpPsiElementImpl.accept(PhpPsiElementImpl.java:73)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$10(InspectionRunner.java:367)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:1075)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$11(InspectionRunner.java:379)
# 	at com.intellij.openapi.application.impl.ReadMostlyRWLock.executeByImpatientReader(ReadMostlyRWLock.java:200)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.executeByImpatientReader(ApplicationImpl.java:184)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$12(InspectionRunner.java:385)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:158)
# 	at com.intellij.util.AstLoadingFilter.forceAllowTreeLoading(AstLoadingFilter.java:150)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$13(InspectionRunner.java:325)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:129)
# 	at com.intellij.util.AstLoadingFilter.disallowTreeLoading(AstLoadingFilter.java:118)
# 	at com.intellij.codeInsight.daemon.impl.InspectionRunner.lambda$processInOrder$14(InspectionRunner.java:325)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.lambda$call$0(JobLauncherImpl.java:307)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$12(CoreProgressManager.java:610)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:685)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:641)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:609)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:78)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:292)
# 	at com.intellij.concurrency.JobLauncherImpl$1MyProcessQueueTask.call(JobLauncherImpl.java:278)
# 	at java.base/java.util.concurrent.ForkJoinTask$AdaptedCallable.exec(ForkJoinTask.java:1428)
# 	at java.base/java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:373)
# 	at java.base/java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1182)
# 	at java.base/java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1655)
# 	at java.base/java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1622)
# 	at java.base/java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:165)
# 2024-03-17 18:43:42,827 [265191447] SEVERE - #c.i.u.IdempotenceChecker - PhpStorm 2023.3.4  Build #PS-233.14475.35
# 2024-03-17 18:43:42,830 [265191450] SEVERE - #c.i.u.IdempotenceChecker - JDK: 17.0.10; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2024-03-17 18:43:42,830 [265191450] SEVERE - #c.i.u.IdempotenceChecker - OS: Linux
# 2024-03-17 18:43:42,830 [265191450] SEVERE - #c.i.u.IdempotenceChecker - Last Action: EditorBackSpace

# %% [markdown]
# You can test your solution using included tests:

# %%
import subprocess
phpServer = subprocess.Popen(['php', '-S', 'localhost:8888', '-t', 'project/public'])

# %%
! cd tests && composer install && vendor/bin/codecept run

# %%
phpServer.kill()
